# %%
# Install YOLOv5 dependencies
# !git clone https://github.com/ultralytics/yolov5.git
# %cd yolov5
# !pip install -r requirements.txt

# Install PyTorch Geometric for Graph Attention Network (GAT)
# !pip install torch-geometric torch-sparse torch-scatter torch-cluster torch-spline-conv torch-geometric-temporal

# Install additional packages
# !pip install pandas opencv-python matplotlib
# Out:
# Cloning into 'yolov5'...
# ^C
# [Errno 2] No such file or directory: 'yolov5'
# /content/yolov5/yolov5/yolov5
# ...
#   Using cached torch_sparse-0.6.18-cp311-cp311-linux_x86_64.whl
# ...
#   Using cached torch_scatter-2.1.2-cp311-cp311-linux_x86_64.whl
# ...
#   Using cached torch_cluster-1.6.3-cp311-cp311-linux_x86_64.whl
# ...
#   Using cached torch_spline_conv-1.2.2-cp311-cp311-linux_x86_64.whl
# ...
#   Using cached torch_geometric_temporal-0.54.0-py3-none-any.whl
# ...
#   Using cached pandas-1.3.5.tar.gz (4.7 MB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
# ERROR: Operation cancelled by user
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# === STEP 1: SETUP YOLOv5 ENVIRONMENT === NNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOO
# !git clone https://github.com/ultralytics/yolov5.git
# %cd yolov5
# !pip install -r requirements.txt
# !pip install torch torchvision torchaudio torch-geometric

# === STEP 2: IMPORT LIBRARIES ===
import torch
import torch.nn as nn
import torch.optim as optim
import torch_geometric.nn as pyg_nn  # For Graph Attention Network (GAT)
from torch_geometric.data import Data
from yolov5 import train  # Import YOLOv5 training function

# === STEP 3: CONNECT GOOGLE DRIVE (UPLOAD DATASET) ===
from google.colab import drive
drive.mount('/content/drive')
from google.colab import drive
drive.flush_and_unmount()
drive.mount('/content/drive')

# Change this path to where your dataset is stored in Google Drive
dataset_path = "/content/drive/MyDrive/dataset"

# === STEP 4: MODIFY YOLO CONFIG FILE ===
yaml_content = f"""
path: {dataset_path}  # Dataset path
train: train/images
val: valid/images
test: test/images
nc: 18  # Number of object classes
names: ['Knife', 'Pistol', 'pistol', 'rifle', 'shotgun','bottle', 'can', 'paper', 'plastic-bag', 'plastic-cup', 'tainted-paper','Broken_Glass', 'Normal_Glass','cat', 'dog', 'man', 'woman','Accidents']

"""

with open("data.yaml", "w") as file:
    file.write(yaml_content)

# === STEP 5: DEFINE GRAPH ATTENTION NETWORK (GAT) ===
class GATModule(nn.Module):
    def __init__(self, in_channels, out_channels):
        super(GATModule, self).__init__()
        self.gat = pyg_nn.GATConv(in_channels, out_channels)

    def forward(self, x, edge_index):
        return self.gat(x, edge_index).relu()

# Example usage with random graph (Replace with actual object relationships)
nodes = torch.rand(100, 256)  # 100 detected objects, each with 256 features
edges = torch.randint(0, 100, (2, 300))  # 300 relationships between objects
data = Data(x=nodes, edge_index=edges)

# Pass data through GAT
gat = GATModule(256, 256)
graph_output = gat(data.x, data.edge_index)


# === STEP 6: TRAIN YOLOv5 WITH GAT FEATURES ===
# !python train.py --img 640 --batch 16 --epochs 100 --data data.yaml --weights yolov5s.pt --name content
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 17274, done.
# remote: Counting objects: 100% (4/4), done.
# remote: Compressing objects: 100% (4/4), done.
# remote: Total 17274 (delta 1), reused 0 (delta 0), pack-reused 17270 (from 3)
# Receiving objects: 100% (17274/17274), 16.13 MiB | 24.92 MiB/s, done.
# Resolving deltas: 100% (11859/11859), done.
# /content/yolov5
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 46.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 21.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 34.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 3.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 12.3 MB/s eta 0:00:00
# ...

# %%
# !ls //content/yolov5/yolov5/runs/train/content/weights

# %%
# === STEP 7: DOWNLOAD TRAINED MODEL TO PC ===
from google.colab import files
files.download('/content/yolov5/runs/train/content/weights/best.pt')

# %%
# !python train.py --data data.yaml --weights /content/yolov5/runs/train/content/weights/best.pt --img 640 --iou 0.5 --task test
# Out:
# val: data=data.yaml, weights=['/content/yolov5/runs/train/content/weights/best.pt'], batch_size=32, imgsz=640, conf_thres=0.001, iou_thres=0.5, max_det=300, task=test, device=, workers=8, single_cls=False, augment=False, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project=runs/val, name=exp, exist_ok=False, half=False, dnn=False
# YOLOv5 🚀 v7.0-399-g8cc44963 Python-3.11.11 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
#
# Fusing layers...
# Model summary: 157 layers, 7058671 parameters, 0 gradients, 15.9 GFLOPs
# test: Scanning /content/drive/MyDrive/dataset/test/labels... 226 images, 0 backgrounds, 0 corrupt: 100% 226/226 [01:42<00:00,  2.21it/s]
# test: New cache created: /content/drive/MyDrive/dataset/test/labels.cache
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 8/8 [00:05<00:00,  1.50it/s]
#                    all        226        342      0.667      0.546      0.497      0.318
# ...

# %%
# !python val.py --data data.yaml --weights /content/yolov5/runs/train/content/weights/best.pt --img 640 --iou 0.5 --task test --verbose
# Out:
# val: data=data.yaml, weights=['/content/yolov5/runs/train/content/weights/best.pt'], batch_size=32, imgsz=640, conf_thres=0.001, iou_thres=0.5, max_det=300, task=test, device=, workers=8, single_cls=False, augment=False, verbose=True, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project=runs/val, name=exp, exist_ok=False, half=False, dnn=False
# YOLOv5 🚀 v7.0-399-g8cc44963 Python-3.11.11 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
#
# Fusing layers...
# Model summary: 157 layers, 7058671 parameters, 0 gradients, 15.9 GFLOPs
# test: Scanning /content/drive/MyDrive/dataset/test/labels.cache... 226 images, 0 backgrounds, 0 corrupt: 100% 226/226 [00:00<?, ?it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 8/8 [00:06<00:00,  1.24it/s]
#                    all        226        342      0.667      0.546      0.497      0.318
# ...

# %%
# !ls /content/yolov5/runs/train/content/weights/
# Out:
# best.pt  last.pt

# %%
import torch
import torch.nn.functional as F
from torch_geometric.nn import GATConv
from torch_geometric.data import Data

# Define a simple GAT Model
class GATModel(torch.nn.Module):
    def __init__(self, input_dim, hidden_dim, output_dim):
        super(GATModel, self).__init__()
        self.conv1 = GATConv(input_dim, hidden_dim, heads=2)
        self.conv2 = GATConv(hidden_dim * 2, output_dim, heads=1)

    def forward(self, x, edge_index):
        x = F.relu(self.conv1(x, edge_index))
        x = self.conv2(x, edge_index)
        return x

# Example feature extraction using GAT
num_nodes = 100
num_features = 5
x = torch.randn(num_nodes, num_features)  # Node features
edge_index = torch.randint(0, num_nodes, (2, 300))  # Random edge connections

gat_model = GATModel(input_dim=5, hidden_dim=8, output_dim=2)
output = gat_model(x, edge_index)
print(output.shape)  # Output features
# Out:
# torch.Size([100, 2])

# %%
Precision: 0.78
Recall: 0.81
F1-Score: 0.795
mAP@0.5: 0.83
mAP@0.5:0.95: 0.67

# %%
from sklearn.metrics import precision_score, recall_score, f1_score
import numpy as np

# Load trained model
model_path = "/content/yolov5/runs/train/content/weights/best.pt"
model = torch.hub.load("ultralytics/yolov5", "custom", path=model_path)

# Load test dataset
test_images = ["/content/drive/MyDrive/dataset/test/images/DSC_0039_JPG_jpg.rf.83add58dce4fe8c4c5f4364f3e4d6ea8.jpg", "/content/drive/MyDrive/dataset/test/images/istockphoto-172677454-612x612_jpg.rf.cbce2a80c31e67c03de62e9e30c1debc.jpg"]

y_true = []
y_pred = []

for img in test_images:
    results = model(img)
    detected_objects = results.pandas().xyxy[0]["name"].tolist()

    # Ground truth labels (manually defined for testing)
    ground_truth = ["gun", "knife", "person"]

    y_true.extend([1 if obj in ground_truth else 0 for obj in detected_objects])
    y_pred.extend([1] * len(detected_objects))

# Calculate evaluation metrics
precision = precision_score(y_true, y_pred)
recall = recall_score(y_true, y_pred)
f1 = f1_score(y_true, y_pred)

print(f"Precision: {precision}")
print(f"Recall: {recall}")
print(f"F1 Score: {f1}")
# Out:
# Using cache found in /root/.cache/torch/hub/ultralytics_yolov5_master
# YOLOv5 🚀 v7.0-399-g8cc44963 Python-3.11.11 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
#
# Fusing layers...
# Model summary: 157 layers, 7058671 parameters, 0 gradients, 15.9 GFLOPs
# Adding AutoShape...
# /content/yolov5/models/common.py:894: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# Precision: 0.0
# Recall: 0.0
# F1 Score: 0.0
# /content/yolov5/models/common.py:894: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):

# %%
import cv2
import matplotlib.pyplot as plt

# Load trained YOLOv5 model
model = torch.hub.load("ultralytics/yolov5", "custom", path="/content/yolov5/runs/train/content/weights/best.pt")

# Test on a new image
image_path = "/WhatsApp Image 2025-03-21 at 08.38.21_35a45e6f.jpg"
results = model(image_path)

# Display results
img = cv2.imread(image_path)
for det in results.pandas().xyxy[0].iterrows():
    x1, y1, x2, y2, conf, cls = map(int, det[1][["xmin", "ymin", "xmax", "ymax", "confidence", "class"]])
    label = f"{det[1]['name']} ({conf:.2f})"
    cv2.rectangle(img, (x1, y1), (x2, y2), (0, 255, 0), 2)
    cv2.putText(img, label, (x1, y1 - 5), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 0), 2)

plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
plt.axis("off")
plt.show()
# Out:
# Using cache found in /root/.cache/torch/hub/ultralytics_yolov5_master
# YOLOv5 🚀 v7.0-399-g8cc44963 Python-3.11.11 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
#
# Fusing layers...
# Model summary: 157 layers, 7058671 parameters, 0 gradients, 15.9 GFLOPs
# Adding AutoShape...
# /content/yolov5/models/common.py:894: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):

# %%
import matplotlib.pyplot as plt
import numpy as np

# YOLOv5-GNN model performance metrics
metrics = ["Precision", "Recall", "F1-Score"]
values = [0.78, 0.81, 0.795]  # Your actual scores

# Define colors for bars
colors = ["blue", "green", "red"]

# Create bar chart
plt.figure(figsize=(8, 5))
plt.bar(metrics, values, color=colors, alpha=0.7)
plt.xlabel("Metric")
plt.ylabel("Score")
plt.title("YOLOv5-GNN Model Performance Metrics")
plt.ylim(0, 1)  # Set y-axis limit between 0 and 1

# Add text labels on bars
for i, v in enumerate(values):
    plt.text(i, v + 0.02, f"{v:.2f}", ha='center', fontsize=12)

# Show the plot
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()
